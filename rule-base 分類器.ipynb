# %%
import numpy
import openpyxl
wb = openpyxl.load_workbook('D:/測試35首.xlsx')
ws = wb.active
myList = [row for row in ws.values]
myArr = numpy.array(myList)
#包含的陣列
friend=[]
family=[]
love=[]
positive=[]
sad=[]
happy=[]
miss=[]
feel=[]
#不包含的陣列
nofriend=[]
nofamily=[]
nolove=[]
nopositive=[]
nosad=[]
nohappy=[]
nomiss=[]
nofeel=[]
#全部有 全部沒
noall=[]
all1=[]
for i in range(1,131):
    sumfriend=0
    sumfamily=0
    sumlove=0
    sumpositive=0
    sumsad=0
    sumhappy=0
    summiss=0
    sumfeel=0
    lyric=myArr[i][3]
    b=lyric.split(" ")
    for j in range(0,len(b)):
        try:  
            if(b[j]=="友情" or b[j]=="朋友" or b[j]=="兄弟" or  b[j]=="摯友" or b[j]=="團員" or 
                b[j]=="情誼" or b[j]=="友誼" or b[j]=="姐妹" or b[j]=="好友"  or b[j]=="好朋友" or b[j]=="十七" or 
                b[j]=="同學" or b[j]=="粉絲"):
                sumfriend=sumfriend+1
            if(b[j]=="媽咪" or b[j]=="兒女" or b[j]=="外婆" or b[j]=="人母"
              or b[j]=="人父" or b[j]=="父親" or b[j]=="母親"or b[j]=="親人"
              or b[j]=="父母"or b[j]=="親情" or b[j]=="家人"or b[j]=="爺爺"):
                sumfamily=sumfamily+1          
            if(b[j]=="戀人" or b[j]=="失戀" or b[j]=="告白" or b[j]=="愛情" or b[j]=="真愛" or b[j]=="愛人" 
               or b[j]=="男友"):
                sumlove=sumlove+1
            if(b[j]=="夢想" or b[j]=="勇敢" or b[j]=="能量" or b[j]=="鼓勵" or b[j]=="無畏" or b[j]=="成長" 
               or b[j]=="逐夢"or b[j]=="自我"or b[j]=="人生"or b[j]=="樂觀" or b[j]=="熱血"or b[j]=="決心" or
              b[j]=="態度" or b[j]=="勇氣" or b[j]=="堅強"):
                sumpositive=sumpositive+1
            if(b[j]=="傷感" or b[j]=="憂傷" or  b[j]=="悲傷" or b[j]=="心痛" or 
                b[j]=="難過" or b[j]=="哀傷" or b[j]=="孤獨" or b[j]=="孤單"):
                sumsad=sumsad+1     
            if(b[j]=="思念" or b[j]=="想起" or  b[j]=="想念" or b[j]=="思鄉" or 
                b[j]=="回憶" or b[j]=="童年" or b[j]=="懷念" or b[j]=="追憶" or b[j]=="相思"):
                summiss=summiss+1
            if(b[j]=="快樂" or b[j]=="熱情" or  b[j]=="歡快" or b[j]=="輕鬆" or 
                b[j]=="歡樂" or b[j]=="愉快" or b[j]=="笑容" or b[j]=="愉悅" or b[j]=="俏皮" or
              b[j]=="活力" or b[j]=="雀躍" or b[j]=="清新"):
                sumhappy=sumhappy+1  
            if(b[j]=="遺憾" or b[j]=="珍惜" or  b[j]=="無奈" or b[j]=="感慨" or 
                b[j]=="社會" or b[j]=="感悟" or b[j]=="訴說"):
                sumfeel=sumfeel+1
        except:
            sumfriend=sumfriend+0
            sumfamily=sumfamily+0
    if sumfriend>0:
        friend.append(myArr[i][1])       
    if sumfamily>0:
        family.append(myArr[i][1])
    if sumlove>0:
        love.append(myArr[i][1])
    if sumpositive>0:
        positive.append(myArr[i][1])
    if sumsad>0:
        sad.append(myArr[i][1])
    if sumhappy>0:
        happy.append(myArr[i][1])
    if summiss>0:
        miss.append(myArr[i][1])
    if sumfeel>0:
        feel.append(myArr[i][1])
    if sumfriend==0:
        nofriend.append(myArr[i][1])
    if sumfamily==0:
        nofamily.append(myArr[i][1])
    if sumlove==0:
        nolove.append(myArr[i][1])
    if sumpositive==0:
        nopositive.append(myArr[i][1])
    if sumsad==0:
        nosad.append(myArr[i][1])
    if sumhappy==0:
        nohappy.append(myArr[i][1])
    if summiss==0:
        nomiss.append(myArr[i][1])
    if sumfeel==0:
        nofeel.append(myArr[i][1])
    if (sumfriend>0 and sumfamily>0 and sumlove>0 and sumsad>0 and sumpositive>0 and sumhappy>0 and summiss>0
       and sumfeel>0):
        all1.append(myArr[i][1])
    if (sumfriend==0 and sumfamily==0 and sumlove==0 and sumsad==0 and sumpositive==0 and sumhappy==0 and summiss==0
       and sumfeel==0):
        noall.append(i)
        noall.append(myArr[i][1])
print("有分到友情的歌:",len(friend))
print("有分到親情的歌:",len(family))
print("有分到愛情的歌:",len(love))
print("有分到正向的歌:",len(positive))
print("有分到悲傷的歌:",len(sad))
print("有分到愉快的歌:",len(happy))
print("有分到想念的歌:",len(miss))
print("有分到感慨的歌:",len(feel))
print("三個都有分到的歌:",len(all1))
print("都沒有分到的歌:",len(noall))
#print("沒分到友情的歌:")
#print(nofriend)
#print("沒分到親情的歌:")
#print(nofamily)
#print()
#print("沒分到的歌:",len(nofriend))
#print(nofriend)
print(noall)
# Out:
# 有分到友情的歌: 23
# 有分到親情的歌: 21
# 有分到愛情的歌: 28
# 有分到正向的歌: 46
# 有分到悲傷的歌: 21
# 有分到愉快的歌: 17
# 有分到想念的歌: 22
# 有分到感慨的歌: 19
# 三個都有分到的歌: 0
# 都沒有分到的歌: 36
# [21, '我不需要每一個人都愛我', 29, '我們來拍張照', 38, '盛夏光年', 50, '唯一', 57, '只怕想家', 81, '當時的我們', 90, '4 號病房', 92, 'Angel', 93, 'DIVA', 97, '隨心所遇', 103, '射手', 104, '黑白切', 106, 'Boom', 108, 'SuperStar', 111, '我會好好的', 113, '第一次愛的人', 115, '我知道我是一個已經過氣的歌手', 116, '玻璃之情']

# %%
import numpy
import openpyxl
wb = openpyxl.load_workbook('D:/第二輪.xlsx')
ws = wb.active
myList = [row for row in ws.values]
myArr = numpy.array(myList)
friend=[]
family=[]
love=[]
positive=[]
sad=[]
nofriend=[]
nofamily=[]
noall=[]
nolove=[]
nopositive=[]
nosad=[]
all1=[]
for i in range(0,633):
    sumfriend=0
    sumfamily=0
    sumlove=0
    sumpositive=0
    sumsad=0
    lyric=myArr[i][3]
    b=lyric.split(" ")
    for j in range(0,len(b)):
        try:
            if (b[j]=="閨蜜" or b[j]=="歌迷" or b[j]=="夢想" or  b[j]=="學生" or b[j]=="觀眾"):
                sumfriend=sumfriend+1
                '''
            if (b[j]=="女兒" or b[j]=="媽媽" or b[j]=="爸爸"):
                sumfamily=sumfamily+1        
            if (model.similarity(b[j],"愛情")>0.686 or model.similarity(b[j],"暗戀")>0.79):
                sumlove=sumlove+1
            if (b[j]=="勵志" or b[j]=="動人心弦" or  b[j]=="希望" or b[j]=="晴朗" 
                or b[j]=="蛻變"  or b[j]=="和平" or  b[j]=="無畏" or b[j]=="不懈"
               or b[j]=="堅毅"  or b[j]=="初心" or  b[j]=="激勵" or b[j]=="渴望"
               or b[j]=="鼓勵"  or b[j]=="追尋" or  b[j]=="毅力" or b[j]=="堅定"):
                sumpositive=sumpositive+1
            if (b[j]=="悲傷" or b[j]=="悲情" or  b[j]=="寂寞" or b[j]=="惆悵" or  b[j]=="刻骨銘心" or 
                b[j]=="痛苦" or b[j]=="情傷" or b[j]=="冷漠"):
                sumsad=sumsad+1
            '''
        except:
            sumfriend=sumfriend+0
            sumlove=sumlove+0
            sumfamily=sumfamily+0
            sumpositive=sumpositive+0
            sumsad=sumsad+0
    if sumfriend>0:
        friend.append(myArr[i][1])       
    if sumfamily>0:
        family.append(myArr[i][1])
    if sumlove>0:
        love.append(myArr[i][1])
    if sumpositive>0:
        positive.append(myArr[i][1])
    if sumsad>0:
        sad.append(myArr[i][1])
    if sumfriend==0:
        nofriend.append(myArr[i][1])
    if sumfamily==0:
        nofamily.append(myArr[i][1])
    if sumlove==0:
        nolove.append(myArr[i][1])
    if sumpositive==0:
        nopositive.append(myArr[i][1])
    if sumsad==0:
        nosad.append(myArr[i][1])
    if sumfriend>0 and sumfamily>0 and sumlove>0:
        all1.append(myArr[i][1])
    if sumlove==0 and sumpositive==0 and sumsad==0:
        noall.append(i)
        print(myArr[i][1])
        print(myArr[i][2])
        print(myArr[i][3])
        print()
print("有分到友情的歌:",len(friend))
print("有分到親情的歌:",len(family))
print("有分到愛情的歌:",len(love))
print("有分到正向的歌:",len(positive))
print("有分到悲傷的歌:",len(sad))
print("三個都有分到的歌:",len(all1))
print("都沒有分到的歌:",len(noall))
#print("沒分到友情的歌:")
#print(nofriend)
#print("沒分到親情的歌:")
#print(nofamily)
#print()
#print("沒分到的歌:",len(nofriend))
#print(nofriend)
#print(noall)
# Out:
# 歌名
# 分類
# 鑑賞斷詞
#
# All in
# 愛情 慢歌
# LIN 黃麗玲 突破性 專輯 捨棄 擅長 情歌 銳減 瞭慢 作品 比例 削弱 流行性 音樂風格 重心 放在 節奏性 風格 鮮明的 中快 演唱 EDM RAP 節奏感 拿捏 有模有樣 展現 駕馭能力
#
# 以前, 以後
# 愛情 悲傷
# 姚若龍 細碎 歌詞 筆觸 流露 一份 純熟 女人味 坦然 心情 已成 未知 的經 傾吐 黃麗玲 大氣 唱腔 給人 留下 深刻的 印象 那份 浪漫 炙熱 被動 冷漠 感嘆 女歌手 輕易 駕馭 難以 抗拒 美感 將會 聆聽 慢慢 發現
#
# 未單身
# 愛情
# 聽眾 熟悉的 黃麗玲 情歌 以往 作品 太過 公式化 演唱 大鳴大放 方式 表現 以突 內斂 內心戲 效果 未必 一聽 喜歡的 耐人尋味 開頭 有如 電影 情節 開幕 法令 驚艷 沉靜 氛圍 娓娓道來 傳遞 強大的 情緒 感染力 她將 那種 放在 心情 唱得 飆高音 深入人心
#
# 我很忙
# 愛情 安慰
# 溫暖 療傷 情歌 成名 黃麗玲 專輯 都會 幾首 標誌性 亮點 新專輯 依然 不滿足 很忙 三首 第一遍 便會 深深 打動 傷感情 三種 疼痛 釋懷 矛盾 心態 壓抑 隱忍 歌聲 女人 角度 都市女性 內心世界 尺度 把握 到位
#
# 隨心所遇
# 愉快
# 自上 專輯 罪惡感 發行 Lin 700 多個 繞著 地球 穿梭 國度 開唱 日子 之際 終於 帶來 瞭從 旅行 靈感 創作 並與 知名 詞人 李焯雄 全新 隨心 所遇 這首 新歌 體會 音樂創作 將在 啓程 不帶 預期 不期而遇 新鮮的 感動
#
# 我知道
# 愛情(幸福)
# 甜美 青澀 動人 初戀 一句 歌詞 帶給 濃濃的 甜蜜 MV 特別 邀請 偶像劇 比賽 男主角 李國毅 By2 姐姐 Miko 搭檔 真情流露 感情戲 感動 惹人 憐惜
#
# 當時的我們
# 慢歌 畢業 友情
# 兩年 發片 By2 新專輯 抒情 主打歌 一經 反響 焦急 等待 歌迷 一首 主打 過癮 期待 專輯 以往 快歌 方式 本次 首波 發布 次日 萬點 擊量 空降 各大 排行榜 前列 畢業 熱門
#
# 射手
# 搖滾 Party 愉快
# ...

# %%
import csv
remainder=[]
for i in range(len(noall)):
    a=[]
    b=myArr[noall[i]][0]
    c=myArr[noall[i]][1]
    d=myArr[noall[i]][2]
    e=myArr[noall[i]][3]
    a.append(b)
    a.append(c)
    a.append(d)
    a.append(e)
    remainder.append(a)
print(remainder)
with open('lyrics.csv','w',encoding='utf-8',newline='') as f: #開啟輸出的CSV檔案
    writer=csv.writer(f) #建立CSV檔寫入器
    for item in remainder:
        writer.writerow((column for column in item))
print('\n讀取 csv 檔')
# Out:
# [['A-Lin', 'All in', '愛情 慢歌', 'LIN 黃麗玲 突破性 專輯 捨棄 擅長 情歌 銳減 瞭慢 作品 比例 削弱 流行性 音樂風格 重心 放在 節奏性 風格 鮮明的 中快 演唱 EDM RAP 節奏感 拿捏 有模有樣 展現 駕馭能力'], ['A-Lin', '以前, 以後', '愛情 悲傷', '姚若龍 細碎 歌詞 筆觸 流露 一份 純熟 女人味 坦然 心情 已成 未知 的經 傾吐 黃麗玲 大氣 唱腔 給人 留下 深刻的 印象 那份 浪漫 炙熱 被動 冷漠 感嘆 女歌手 輕易 駕馭 難以 抗拒 美感 將會 聆聽 慢慢 發現'], ['A-Lin', '未單身', '愛情', '聽眾 熟悉的 黃麗玲 情歌 以往 作品 太過 公式化 演唱 大鳴大放 方式 表現 以突 內斂 內心戲 效果 未必 一聽 喜歡的 耐人尋味 開頭 有如 電影 情節 開幕 法令 驚艷 沉靜 氛圍 娓娓道來 傳遞 強大的 情緒 感染力 她將 那種 放在 心情 唱得 飆高音 深入人心'], ['A-Lin', '我很忙', '愛情 安慰', '溫暖 療傷 情歌 成名 黃麗玲 專輯 都會 幾首 標誌性 亮點 新專輯 依然 不滿足 很忙 三首 第一遍 便會 深深 打動 傷感情 三種 疼痛 釋懷 矛盾 心態 壓抑 隱忍 歌聲 女人 角度 都市女性 內心世界 尺度 把握 到位'], ['A-Lin', '隨心所遇', '愉快', '自上 專輯 罪惡感 發行 Lin 700 多個 繞著 地球 穿梭 國度 開唱 日子 之際 終於 帶來 瞭從 旅行 靈感 創作 並與 知名 詞人 李焯雄 全新 隨心 所遇 這首 新歌 體會 音樂創作 將在 啓程 不帶 預期 不期而遇 新鮮的 感動'], ['BY2', '我知道', '愛情(幸福)', '甜美 青澀 動人 初戀 一句 歌詞 帶給 濃濃的 甜蜜 MV 特別 邀請 偶像劇 比賽 男主角 李國毅 By2 姐姐 Miko 搭檔 真情流露 感情戲 感動 惹人 憐惜'], ['BY2', '當時的我們', '慢歌 畢業 友情', '兩年 發片 By2 新專輯 抒情 主打歌 一經 反響 焦急 等待 歌迷 一首 主打 過癮 期待 專輯 以往 快歌 方式 本次 首波 發布 次日 萬點 擊量 空降 各大 排行榜 前列 畢業 熱門'], ['MP魔幻力量',
# ...

# %%
#把array轉換成字典
dicts={}
for i in range(len(friend)):
    if  friend[i] not in dicts:
        dicts[friend[i]]=1
    #else :
        #dict[friend[i]]=dict[friend[i]]+1
print(dicts)
print(len(dicts))
# Out:
# {'好朋友的祝福': 1, '花': 1, '等等我': 1, '十七': 1, '不說再見': 1, '致每個你': 1, '給你': 1, '我們的時光': 1, '真心話太冒險': 1, '剩下的盛夏': 1, '乾啦乾啦': 1, '一千個世紀': 1, '垃圾車': 1, '軋車': 1, '二人遊': 1, '味道': 1, 'BFF': 1, 'GotYourBack': 1, 'WEWILLRULE背水一戰': 1, '朋友的酒': 1, '那些愛過的事': 1, '阿比安吉': 1, '無朋友': 1, '萍聚': 1, '老友記': 1, '最後的戰役': 1, '療傷燒肉粽': 1, '不可能是不可能的事': 1, '不流淚的機場': 1, '陌生老朋友': 1, '飛機': 1, '我不能忘記你': 1, '暮光': 1, '聽你說(郁可唯&林凡)': 1, '螺絲釘': 1, '我很愉快': 1, '糖果粉碎者 (feat. 盧凱彤)': 1, '晴雅集': 1, '莫忘初衷': 1, '當年情': 1, '姐妹': 1, '依賴': 1, '往未來飛的客機': 1, '聊天': 1, '嫁妝': 1, '勿忘我': 1, '逗陣兄弟': 1, '濱河東路': 1, '我朋友': 1, '天使之翼': 1, '其實我們值得幸褔': 1, '一路不變': 1, '地痞': 1, '鼓聲若響': 1, '寫信回家': 1, '我的大學': 1, '方圓幾里': 1, '為你寫首歌': 1, '下雨的夜晚': 1, '空氣中的視聽與幻覺': 1, '當我們一起走過': 1}
# 61

# %%
import numpy
import openpyxl
wb = openpyxl.load_workbook('愛情 700(p欄.15).xlsx')
ws = wb.active
myList = [row for row in ws.values]
myArr = numpy.array(myList)
friend=[]
nofriend=[]
for i in range(1,701):
    sum1=0
    lyric=myArr[i][6]
    b=lyric.split(" ")
    for j in range(0,len(b)):
        try:
            if (b[j]=="戀人" or b[j]=="失戀" or b[j]=="告白" or b[j]=="愛情" or b[j]=="真愛" or b[j]=="愛人" 
               or b[j]=="男友"):
                sum1=sum1+1
        except:
            sum1=sum1+0
    if sum1>0:
        friend.append(myArr[i][1])
    elif sum1==0:
        nofriend.append(myArr[i][1])
        #print("歌手:"+myArr[i][0])
        print("歌名:"+myArr[i][1])
        print("分類:"+myArr[i][5])
        print("斷詞內容: "+myArr[i][6])
        print()

print("有分到的歌:",len(friend))
#print(friend)
#print()
print("沒分到的歌:",len(nofriend))
#print(nofriend)

# %%
def cutword(a):
    import jieba
    from collections import Counter
    import openpyxl
    import numpy

    jieba.set_dictionary('D:/專題/dict.txt.big')
    jieba.load_userdict('D:/專題/userdict.txt') 
    with open('D:/專題/stops.txt', 'r', encoding='utf8') as f: 
        stops = f.read().split('\n')
    data=[]
    sentence=[]
    
    sentences = a.split()
    sent_words = [list(jieba.cut(sent0)) for sent0 in sentences if sent0 not in stops]
    document = [" ".join(sent0) for sent0 in sent_words]
    tfidf_model6 = TfidfVectorizer(max_features=15).fit(document)
    for key in tfidf_model6.vocabulary_:
        sentence.append(key)
    data.append(sentence)
    return sentence
def classfier1(b):
    dict={}
    class1=[]
    sum1=0
    for j in range(0,len(b)):
        try:
            if(b[j]=="友情" or b[j]=="朋友" or b[j]=="兄弟" or  b[j]=="摯友" or b[j]=="團員" or 
                b[j]=="情誼" or b[j]=="友誼" or b[j]=="姐妹" or b[j]=="好友"  or b[j]=="好朋友" or b[j]=="十七" or 
                b[j]=="同學" or b[j]=="粉絲"):
                if("友情" not in dict):
                    dict["友情"]="友情"
            if(b[j]=="媽咪" or b[j]=="兒女" or b[j]=="外婆" or b[j]=="人母"
              or b[j]=="人父" or b[j]=="父親" or b[j]=="母親"or b[j]=="親人"
              or b[j]=="父母"or b[j]=="親情" or b[j]=="家人"or b[j]=="爺爺"):
                if("親情" not in dict):
                    dict["親情"]="親情"       
            if(b[j]=="戀人" or b[j]=="失戀" or b[j]=="告白" or b[j]=="愛情" or b[j]=="真愛" or b[j]=="愛人" 
               or b[j]=="男友"):
                if("愛情" not in dict):
                    dict["愛情"]="愛情"
            if(b[j]=="夢想" or b[j]=="勇敢" or b[j]=="能量" or b[j]=="鼓勵" or b[j]=="無畏" or b[j]=="成長" 
               or b[j]=="逐夢"or b[j]=="自我"or b[j]=="人生"or b[j]=="樂觀" or b[j]=="熱血"or b[j]=="決心" or
              b[j]=="態度" or b[j]=="勇氣" or b[j]=="堅強" or b[j]=="振奮"):
                if("正向" not in dict):
                    dict["正向"]="正向"
            if(b[j]=="傷感" or b[j]=="憂傷" or  b[j]=="悲傷" or b[j]=="心痛" or 
                b[j]=="難過" or b[j]=="哀傷" or b[j]=="孤獨" or b[j]=="孤單"):
                if("悲傷" not in dict):
                    dict["悲傷"]="悲傷"  
            if(b[j]=="思念" or b[j]=="想起" or  b[j]=="想念" or b[j]=="思鄉" or 
                b[j]=="回憶" or b[j]=="童年" or b[j]=="懷念" or b[j]=="追憶" or b[j]=="相思"):
                if("想念" not in dict):
                    dict["想念"]="想念"
            if(b[j]=="快樂" or b[j]=="熱情" or  b[j]=="歡快" or b[j]=="輕鬆" or 
                b[j]=="歡樂" or b[j]=="愉快" or b[j]=="笑容" or b[j]=="愉悅" or b[j]=="俏皮" or
              b[j]=="活力" or b[j]=="雀躍" or b[j]=="清新"):
                if("愉快" not in dict):
                    dict["愉快"]="愉快"
            if(b[j]=="遺憾" or b[j]=="珍惜" or  b[j]=="無奈" or b[j]=="感慨" or 
                b[j]=="社會" or b[j]=="感悟" or b[j]=="訴說"):
                if("感慨" not in dict):
                    dict["感慨"]="感慨"
        except:
            sum1=sum1+0
    #print("dict",dict)
    if (len(dict)==0):
        remainder=b
    else:
        new=zip(dict.keys())
        a=list(new)
        for i in range(len(a)):
            class1.append(a[i][0])
        remainder=[]
        #print(class1,remainder)
    return remainder,class1
def classfier2(b):
    dict={}
    sum1=0
    class1=[]
    for j in range(0,len(b)):
        try:
            if (b[j]=="閨蜜" or b[j]=="歌迷" or b[j]=="夢想" or  b[j]=="學生" or b[j]=="觀眾"):
                if("友情" not in dict):
                    dict["友情"]="友情"
            if (b[j]=="女兒" or b[j]=="媽媽" or b[j]=="爸爸"):
                if("親情" not in dict):
                    dict["親情"]="親情"
            if (b[j]=="情感" or b[j]=="深情" or b[j]=="戀愛" or b[j]=="分手" or b[j]=="浪漫" or b[j]=="感情" 
               or b[j]=="初戀" or b[j]=="情歌" or b[j]=="情人" or b[j]=="幸福"):
                if("愛情" not in dict):
                    dict["愛情"]="愛情"
            if (b[j]=="生活" or b[j]=="力量" or b[j]=="生命力" or b[j]=="成功"):
                if("正向" not in dict):
                    dict["正向"]="正向"
            if (b[j]==" 低落" or b[j]==" 淹沒" or b[j]==" 憂愁" or b[j]==" 心酸" or b[j]==" 痛哭流涕" or 
                b[j]==" 傷心" or b[j]==" 痛苦" or b[j]==" 鬱悶" or b[j]==" 傷口" or b[j]==" 無助" or b[j]==" 艱難" or 
                b[j]==" 失魂落魄" or b[j]==" 落淚" or b[j]==" 體悟"):
                if("悲傷" not in dict):
                    dict["悲傷"]="悲傷"
        except:
            sum1=sum1+0
    #print("dict",dict)
    if (len(dict)==0):
        remainder=b
    else:
        new=zip(dict.keys())
        a=list(new)
        for i in range(0,len(a)):
            class1.append(a[i][0])
        remainder=[]
    return remainder,class1
def classfier3(b):
    dict={}
    sum1=0
    class1=[]
    for j in range(0,len(b)):
        try:
            if (b[j]=="勵志" or b[j]=="動人心弦" or  b[j]=="希望" or b[j]=="晴朗" 
                or b[j]=="蛻變"  or b[j]=="和平" or  b[j]=="無畏" or b[j]=="不懈"
               or b[j]=="堅毅"  or b[j]=="初心" or  b[j]=="激勵" or b[j]=="渴望"
               or b[j]=="鼓勵"  or b[j]=="追尋" or  b[j]=="毅力" or b[j]=="堅定"):
                if("正向" not in dict):
                    dict["正向"]="正向"
            if (b[j]=="傷感" or b[j]=="無奈" or  b[j]=="憂傷" or b[j]=="悲傷" or b[j]=="感傷" 
                or b[j]=="心痛" or b[j]=="難過" or b[j]=="哀傷" or b[j]=="孤獨"):
                if("悲傷" not in dict):
                    dict["悲傷"]="悲傷"
        except:
            sum1=sum1+0
    if (len(dict)==0):
        remainder=b
    else:
        new=zip(dict.keys())
        a=list(new)
        for i in range(len(a)):
            class1.append(a[i][0])
        remainder=[]
    return remainder,class1
from sklearn.feature_extraction.text import TfidfVectorizer
song=[]
class1=[]
query2 = input("\n歌手:")
query = input("\n歌名:")
query3=input("\n歌詞:")
query4=input("\n歌取鑑賞:")
query5=input("\n youtube id:")
query6=input("\n youtube 網址:")
song.append(query2)
song.append(query)
song.append(query3)
song.append(query4)
print(song)
answer=cutword(song[3])
print(answer)
lyrics=cutword(song[2])
print(lyrics)
#print(answer)
remainder,class1=classfier1(answer)

#print("aaa",remainder)
#print("bbb",class1)
if(len(remainder)!=0):
    remainder,class1=classfier2(remainder)
    #print("ccc",remainder)
    #print("ddd",class1)
    if(len(remainder)!=0):
        remainder,class1=classfier3(remainder)
        if(len(remainder)!=0):
            print("no")
        else:
            #print("ccc",remainder)
            print("第三輪",class1)
    else:
        print("第二輪:",class1)
else:
    print("第一輪",class1)
# Out:
# 歌手:12
#
# 歌名:34
#
# 歌詞:是一個通訊和協同運作軟體，它整合了聊天、視訊會議、 文件儲存 、Office 365等功能。Microsoft Teams是Slack等服務的競爭對手。微軟在紐約的一場活動中披露了Microsoft Teams產品
#
# 歌取鑑賞:是一個通訊和協同運作軟體，它整合了聊天、視訊會議、 文件儲存 、Office 365等功能。Microsoft Teams是Slack等服務的競爭對手。微軟在紐約的一場活動中披露了Microsoft Teams產品
#
#  youtube id:23
#
#  youtube 網址:45
# Building prefix dict from D:\專題\dict.txt.big ...
# Loading model from cache C:\Users\Yvonne\AppData\Local\Temp\jieba.u5a6d6b8a6c1dd573bb89d5afb9009229.cache
# ['12', '34', '是一個通訊和協同運作軟體，它整合了聊天、視訊會議、 文件儲存 、Office 365等功能。Microsoft Teams是Slack等服務的競爭對手。微軟在紐約的一場活動中披露了Microsoft Teams產品', '是一個通訊和協同運作軟體，它整合了聊天、視訊會議、 文件儲存 、Office 365等功能。Microsoft Teams是Slack等服務的競爭對手。微軟在紐約的一場活動中披露了Microsoft Teams產品']
# Loading model cost 3.596 seconds.
# Prefix dict has been built successfully.
# Building prefix dict from D:\專題\dict.txt.big ...
# Loading model from cache C:\Users\Yvonne\AppData\Local\Temp\jieba.u5a6d6b8a6c1dd573bb89d5afb9009229.cache
# ...

# %%
def case1(b):
    dict1={}
    classcase1=[]
    sum2=0
    try:
        for j in range(0,len(b)):
            if(b[j]=="結婚" or b[j]=="婚禮" or  b[j]=="求婚" or b[j]=="戀人" or 
                b[j]=="戀愛" or b[j]=="浪漫" or b[j]=="愛情" or b[j]=="熱戀" or b[j]=="甜蜜"):
                if("婚禮" not in dict1):
                    dict1["婚禮"]="婚禮"
            if(b[j]=="魅力" or b[j]=="跳動" or  b[j]=="舞動" or b[j]=="狂歡的" or 
                b[j]=="跳舞" or b[j]=="唱跳" or b[j]=="搖滾" or b[j]=="饒舌" or b[j]=="派對"  or b[j]=="舞力"):
                if("party" not in dict1):
                    dict1["party"]="party"
            if(b[j]=="舞蹈" or b[j]=="奔跑" or  b[j]=="青春" or b[j]=="動感" or 
                b[j]=="活躍" or b[j]=="能量" or b[j]=="精神" or b[j]=="熱戀" or b[j]=="扭動"):
                if("運動會" not in dict1):
                    dict1["運動會"]="運動會"
            if(b[j]=="歲月" or b[j]=="盛夏" or b[j]=="畢業"):
                if("畢業" not in dict1):
                    dict1["畢業"]="畢業"
    except:
        sum2=sum2+0
    if (len(dict1)==0):
        remainder1=b
    else:
        b1=zip(dict1.keys())
        a1=list(b1)
        for i in range(len(a1)):
            classcase1.append(a1[i][0])
        remainder1=[]
    return remainder1,classcase1
def case2(b):
    dict1={}
    classcase1=[]
    sum2=0
    for j in range(0,len(b)):
        try:
            if(b[j]=="求愛"):
                if("婚禮" not in dict1):
                    dict1["婚禮"]="婚禮"
                    print("1")
            if(b[j]=="電音" or  b[j]=="舞蹈" or b[j]=="電子" or b[j]=="熱舞" or b[j]=="動感"):
                if("party" not in dict1):
                    dict1["party"]="party"
                    print("2")
            if(b[j]==" 熱血沸騰" or b[j]=="夏日"or b[j]=="運動會"):
                if("運動會" not in dict1):
                    dict1["運動會"]="運動會"
                    print("3")
            if(b[j]=="校園" or b[j]=="畢業季"):
                if("畢業" not in dict1):
                    dict1["畢業"]="畢業"
                    print("4")
        except:
            sum2=sum2+0
    if (len(dict1)==0):
        remainder1=b
    else:
        b1=zip(dict1.keys())
        a1=list(b1)
        for i in range(len(a1)):
            classcase1.append(a1[i][0])
        remainder1=[]
    return remainder1,classcase1
#answer=cutword(song[3])
#print(answer)
remainder,classcase1=case1(answer)
#print("aaa",remainder)
#print("bbb",classcase1)
if(len(remainder)!=0):
    remainder,classcase1=case2(remainder)
    #print(remainder,classcase1)
    if(remainder!=0):
        print("no")
    else:
        #print("ccc",remaindeer)
        print("第二輪(場合)",clascases1)
else:
    print("第一輪(場合)",classcase1)
# Out:
# 第一輪(場合) ['畢業']

# %%
final=[]
final.append(query2)
final.append(query)
final.append(query5)
final.append(query6)
s=""
goodcut=""
lyricscut=""
for i in range(0,len(class1)):#鑑賞分類
    s=s+class1[i]+" "
for i in range(0,len(classcase1)):#場合分類
    s=s+classcase1[i]+" "
final.append(s)
final.append(query4)#鑑賞
for i in range(0,len(answer)):#鑑賞分類
    goodcut=goodcut+answer[i]+" "
final.append(goodcut)
final.append(query3)#歌詞
for i in range(0,len(lyrics)):#鑑賞分類
    lyricscut=lyricscut+lyrics[i]+" "
final.append(lyricscut)
print(final)
all1=[]
all1.append(final)
import csv
with open('lyrics.csv','w',encoding='utf-8',newline='') as f: #開啟輸出的CSV檔案
    writer=csv.writer(f) #建立CSV檔寫入器
    for item in all1:
        writer.writerow((column for column in item))
#print('\n讀取 csv 檔')
# Out:
# ['1', '2', '3', '4', '想念 畢業 ', '怪獸的曲，阿信的詞，石頭跟諺明的學生故事，復古音色的回憶在彈子房裡甦醒。每一個男生都有過的一段經歷，每一個我們都在追逐的九號球畢業', '怪獸 阿信 石頭 諺明 學生 故事 復古 音色 回憶 彈子房 甦醒 男生 有過 經歷 追逐 九號球 畢業 ', '逃走翻過圍牆只能逃走闖的出口奔向自由熟悉角落有人在等有挑釁的笑容今天誰先開球讓誰嘗點苦頭綠色地平線上撞彩色墮落也許這一桿又沒辦法進球就像的生活一直在出差錯也許這一生始終在追逐那顆九號球卻忘了是誰在愛卻忘了是誰在罩從前背包裝滿自以為的夢狠狠衝過頭未來們要怎麼活凝視白球暫時不去想天空漸漸變紅影子爬滿球桌輸贏沒有結果像人生難以捉摸也許這一桿又沒辦法進球就像的生活一直在出差錯也許這一生始終在追逐那顆九號球卻忘了是誰在愛卻忘了是誰在罩', '逃走 翻過 圍牆 出口 奔向 自由 熟悉 角落 挑釁的 笑容 開球 嘗點 苦頭 綠色 地平線 彩色 墮落 桿又 沒辦法 進球 生活 出差錯 始終 追逐 那顆 九號球 忘了 愛卻 背包 裝滿 自以為 狠狠 衝過 凝視 白球 暫時 天空 漸漸 變紅 影子 爬滿 球桌 輸贏 人生 難以捉摸 ']
